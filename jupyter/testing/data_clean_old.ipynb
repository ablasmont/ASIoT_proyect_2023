# %% [markdown]
# ### Variables
# - **net_manager**: code of the regional network manager
# - **purchase_area**: code of the area where the energy is purchased
# - **street**: Name of the street
# - **zipcode_from and zipcode_to**: 2 columns for the range of zipcodes covered, 4 numbers and 2 letters
# - **city**: Name of the city
# - **num_connections**: Number of connections in the range of zipcodes
# - **delivery_perc**: percentage of the net consumption of electricity or gas. The lower, the more energy was given back to the grid (for example if you have solar panels)
# - **perc_of_active_connections**: Percentage of active connections in the zipcode range
# - **type_of_connection**: principal type of connection in the zipcode range. For electricity is # fuses X # ampère. For gas is G4, G6, G10, G16, G25
# - **type_conn_perc**: percentage of presence of the principal type of connection in the zipcode range
# - **annual_consume**: Annual consume. Kwh for electricity, m3 for gas
# - **annual_consume_lowtarif_perc**: Percentage of consume during the low tarif hours. From 10 p.m. to 7 a.m. and during weekends.
# - **smartmeter_perc**: percentage of smartmeters in the zipcode ranges

# %%
# Importing liabraries
import numpy as np
import pandas as pd
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# #### Import all de datasets

# %%
# Coteq
dfco_13=pd.read_csv("../data/Electricity/coteq_electricity_2013.csv")
dfco_14=pd.read_csv("../data/Electricity/coteq_electricity_2014.csv")
dfco_15=pd.read_csv("../data/Electricity/coteq_electricity_2015.csv")
dfco_16=pd.read_csv("../data/Electricity/coteq_electricity_2016.csv")
dfco_17=pd.read_csv("../data/Electricity/coteq_electricity_2017.csv")
dfco_18=pd.read_csv("../data/Electricity/coteq_electricity_2018.csv")
dfco_19=pd.read_csv("../data/Electricity/coteq_electricity_2019.csv")
dfco_20=pd.read_csv("../data/Electricity/coteq_electricity_2020.csv")

# Endinet
dfendi_13=pd.read_csv("../data/Electricity/endinet_electricity_01012013.csv")
dfendi_14=pd.read_csv("../data/Electricity/endinet_electricity_01012014.csv")
dfendi_15=pd.read_csv("../data/Electricity/endinet_electricity_01012015.csv")
dfendi_16=pd.read_csv("../data/Electricity/endinet_electricity_01012016.csv")

# Enduris
dfendur_13=pd.read_csv("../data/Electricity/enduriselectricity_01012013.csv")
dfendur_14=pd.read_csv("../data/Electricity/enduriselectricity_01012014.csv")
dfendur_15=pd.read_csv("../data/Electricity/enduriselectricity_01012015.csv")
dfendur_16=pd.read_csv("../data/Electricity/enduriselectricity_01012016.csv")
dfendur_17=pd.read_csv("../data/Electricity/enduriselectricity_01012017.csv")
dfendur_18=pd.read_csv("../data/Electricity/enduriselectricity_01012018.csv")
dfendur_19=pd.read_csv("../data/Electricity/enduriselectricity_01012019.csv")

# Enexis
dfen_13=pd.read_csv("../data/Electricity/enexis_electricity_01012013.csv")
dfen_14=pd.read_csv("../data/Electricity/enexis_electricity_01012014.csv")
dfen_15=pd.read_csv("../data/Electricity/enexis_electricity_01012015.csv")
dfen_16=pd.read_csv("../data/Electricity/enexis_electricity_01012016.csv")
dfen_17=pd.read_csv("../data/Electricity/enexis_electricity_01012017.csv")
dfen_18=pd.read_csv("../data/Electricity/enexis_electricity_01012018.csv")
dfen_19=pd.read_csv("../data/Electricity/enexis_electricity_01012019.csv")
dfen_20=pd.read_csv("../data/Electricity/enexis_electricity_01012020.csv")

# Liander
dfli_13=pd.read_csv("../data/Electricity/liander_electricity_01012013.csv")
dfli_14=pd.read_csv("../data/Electricity/liander_electricity_01012014.csv")
dfli_15=pd.read_csv("../data/Electricity/liander_electricity_01012015.csv")
dfli_16=pd.read_csv("../data/Electricity/liander_electricity_01012016.csv")
dfli_17=pd.read_csv("../data/Electricity/liander_electricity_01012017.csv")
dfli_18=pd.read_csv("../data/Electricity/liander_electricity_01012018.csv")
dfli_19=pd.read_csv("../data/Electricity/liander_electricity_01012019.csv")
dfli_20=pd.read_csv("../data/Electricity/liander_electricity_01012020.csv")

# Rendo
dfren_13=pd.read_csv("../data/Electricity/rendo_electricity_2013.csv")
dfren_14=pd.read_csv("../data/Electricity/rendo_electricity_2014.csv")
dfren_15=pd.read_csv("../data/Electricity/rendo_electricity_2015.csv")
dfren_16=pd.read_csv("../data/Electricity/rendo_electricity_2016.csv")
dfren_17=pd.read_csv("../data/Electricity/rendo_electricity_2017.csv")
dfren_18=pd.read_csv("../data/Electricity/rendo_electricity_2018.csv")
dfren_19=pd.read_csv("../data/Electricity/rendo_electricity_2019.csv")

# Stedin
dfst_13=pd.read_csv("../data/Electricity/stedin_electricity_2013.csv")
dfst_14=pd.read_csv("../data/Electricity/stedin_electricity_2014.csv")
dfst_15=pd.read_csv("../data/Electricity/stedin_electricity_2015.csv")
dfst_16=pd.read_csv("../data/Electricity/stedin_electricity_2016.csv")
dfst_17=pd.read_csv("../data/Electricity/stedin_electricity_2017.csv")
dfst_18=pd.read_csv("../data/Electricity/stedin_electricity_2018.csv")
dfst_19=pd.read_csv("../data/Electricity/stedin_electricity_2019.csv")
dfst_20=pd.read_csv("../data/Electricity/stedin_electricity_2020.csv")

# Westland
dfwest_13=pd.read_csv("../data/Electricity/westland-infra_electricity_2013.csv")
dfwest_14=pd.read_csv("../data/Electricity/westland-infra_electricity_2014.csv")
dfwest_15=pd.read_csv("../data/Electricity/westland-infra_electricity_2015.csv")
dfwest_16=pd.read_csv("../data/Electricity/westland-infra_electricity_2016.csv")
dfwest_17=pd.read_csv("../data/Electricity/westland-infra_electricity_2017.csv")
dfwest_18=pd.read_csv("../data/Electricity/westland-infra_electricity_2018.csv")
dfwest_19=pd.read_csv("../data/Electricity/westland-infra_electricity_2019.csv")
dfwest_20=pd.read_csv("../data/Electricity/westland-infra_electricity_2020.csv")

# %%
concat_df=[dfco_13,dfco_14,dfco_15,dfco_16,dfco_17,dfco_18,dfco_19,dfco_20,
    dfendi_13,dfendi_14,dfendi_15,dfendi_16,
    dfendur_13,dfendur_14,dfendur_15,dfendur_16,dfendur_17,dfendur_18,dfendur_19,
    dfen_13,dfen_14,dfen_15,dfen_16,dfen_17,dfen_18,dfen_19,dfen_20,
    dfli_13,dfli_14,dfli_15,dfli_16,dfli_17,dfli_18,dfli_19,dfli_20,
    dfren_13,dfren_14,dfren_15,dfren_16,dfren_17,dfren_18,dfren_19,
    dfst_13,dfst_14,dfst_15,dfst_16,dfst_17,dfst_18,dfst_19,dfst_20,
    dfwest_13,dfwest_14,dfwest_15,dfwest_16,dfwest_17,dfwest_18,dfwest_19,dfwest_20
    ]

# %%
concat=pd.concat(concat_df, axis=0 , sort=False)

# %%
print (concat.shape)
print (concat.dtypes)
# Out:
# (2867621, 17)
# net_manager                      object
# purchase_area                    object
# street                           object
# zipcode_from                     object
# zipcode_to                       object
# city                             object
# num_connections                 float64
# delivery_perc                   float64
# perc_of_active_connections      float64
# type_conn_perc                   object
# type_of_connection               object
# annual_consume                  float64
# annual_consume_lowtarif_perc    float64
# smartmeter_perc                 float64
# ï»¿NETBEHEERDER                 float64
# STANDAARDDEVIATIE                object
# %Defintieve aansl (NRM)         float64
# dtype: object

# %%
data = concat.drop(columns=["ï»¿NETBEHEERDER","STANDAARDDEVIATIE","%Defintieve aansl (NRM)","annual_consume_lowtarif_perc","zipcode_from","zipcode_to", "num_connections", "perc_of_active_connections", "type_conn_perc", "type_of_connection"])

# %%
data.dtypes
# Out:
# net_manager                    object
# purchase_area                  object
# street                         object
# zipcode_from                   object
# zipcode_to                     object
# city                           object
# num_connections               float64
# delivery_perc                 float64
# perc_of_active_connections    float64
# type_conn_perc                 object
# type_of_connection             object
# annual_consume                float64
# smartmeter_perc               float64
# dtype: object

# %%
cities = data["city"]
cities=''.join(str(cities.sort_values().unique().tolist()))
# print("Valores únicos: " + cities)
len(cities)
# Out:
# 35192

# %%
data[(data.net_manager.isna()) | (data.purchase_area.isna()) | (data.street.isna()) | (data.zipcode_from.isna()) | (data.zipcode_to.isna()) | (data.city.isna()) | (data.num_connections.isna()) | (data.delivery_perc.isna()) | (data.perc_of_active_connections.isna()) | (data.type_conn_perc.isna()) | (data.type_of_connection.isna()) | (data.annual_consume.isna()) | (data.smartmeter_perc.isna())]
# Out:
#         net_manager       purchase_area               street zipcode_from  \
# 0           Endinet  871688700000002681              Buizerd       5508KC
# 1           Endinet  871688700000002681             Hertgang       5508LC
# 2           Endinet  871688700000002681             Hertgang       5508LR
# 3           Endinet  871688700000002681             Hertgang       5508LR
# 4           Endinet  871688700000002681         Strijpsebaan       5508RB
# ...             ...                 ...                  ...          ...
# 1482  8716912000008  871691280000000008  Burg G W Stroinkweg       8343XK
# 1483  8716912000008  871691280000000008  Burg G W Stroinkweg       8343XL
# 1484  8716912000008  871691280000000008  Burg G W Stroinkweg       8343XM
# 1485  8716912000008  871691280000000008            Leemkoele       8343XN
# 1486  8716912000008  871691280000000008              De Klim       8343XP
#
#      zipcode_to       city  num_connections  delivery_perc  \
# ...
