# %%
# Python
import pandas as pd
from prophet import Prophet

# %%
# Python
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
# Python
m = Prophet()
m.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# c:\Users\alvar\anaconda3\envs\asiot\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# c:\Users\alvar\anaconda3\envs\asiot\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\alvar\anaconda3\envs\asiot\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.213978    7.479838    8.919025
# 3266 2017-01-16  8.539051    7.766085    9.262561
# 3267 2017-01-17  8.326490    7.577807    9.013504
# 3268 2017-01-18  8.159151    7.371005    8.871555
# 3269 2017-01-19  8.171109    7.406365    8.938030

# %%
# Python
fig1 = m.plot(forecast)

# %%
# Python
fig2 = m.plot_components(forecast)
# Out:
# c:\Users\alvar\anaconda3\envs\asiot\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# c:\Users\alvar\anaconda3\envs\asiot\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
# Python
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 # Python
#       2 from prophet.plot import plot_plotly, plot_components_plotly
# ----> 4 plot_plotly(m, forecast)
#
# File c:\Users\alvar\anaconda3\envs\asiot\lib\site-packages\prophet\plot.py:590, in plot_plotly(m, fcst, uncertainty, plot_cap, trend, changepoints, changepoints_threshold, xlabel, ylabel, figsize)
#     588 data = []
#     589 # Add actual
# --> 590 data.append(go.Scatter(
#     591     name='Actual',
#     592     x=m.history['ds'],
#     593     y=m.history['y'],
#     594     marker=dict(color=actual_color, size=marker_size),
#     595     mode='markers'
#     596 ))
#     597 # Add lower bound
#     598 if uncertainty and m.uncertainty_samples:
#
# NameError: name 'go' is not defined
